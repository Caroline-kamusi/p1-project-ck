# %% [markdown]
# # Aviation Accident Database and Synopses,up to 2023

# %% [markdown]
# ## project overview

# %% [markdown]
# For this project, you will use data cleaning, imputation, analysis, and visualization to generate insights for a business stakeholder.

# %% [markdown]
# I'll start by importing data analysis and visualisation Python libraries and then read in the dataset as a Pandas Dataframe using read_csv()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %%
# load data  to read the dataset
df = pd.read_csv('AviationData.csv', encoding='ISO-8859-1')
df
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12160\3347776229.py:2: DtypeWarning: Columns (6,7,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('AviationData.csv', encoding='ISO-8859-1')
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0      20001218X45444           Accident      SEA87LA080  1948-10-24
# 1      20001218X45447           Accident      LAX94LA336  1962-07-19
# 2      20061025X01555           Accident      NYC07LA005  1974-08-30
# 3      20001218X45448           Accident      LAX96LA321  1977-06-19
# 4      20041105X01764           Accident      CHI79FA064  1979-08-02
# ...               ...                ...             ...         ...
# 88884  20221227106491           Accident      ERA23LA093  2022-12-26
# 88885  20221227106494           Accident      ERA23LA095  2022-12-26
# 88886  20221227106497           Accident      WPR23LA075  2022-12-26
# ...

# %%
# CHECKING THE SHAPE OF THE DATASET
df.shape
# Out:
# (88889, 31)

# %%
# checking the head of the data
df. head()
# Out:
#          Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0  20001218X45444           Accident      SEA87LA080  1948-10-24
# 1  20001218X45447           Accident      LAX94LA336  1962-07-19
# 2  20061025X01555           Accident      NYC07LA005  1974-08-30
# 3  20001218X45448           Accident      LAX96LA321  1977-06-19
# 4  20041105X01764           Accident      CHI79FA064  1979-08-02
#
#           Location        Country   Latitude  Longitude Airport.Code  \
# 0  MOOSE CREEK, ID  United States        NaN        NaN          NaN
# 1   BRIDGEPORT, CA  United States        NaN        NaN          NaN
# 2    Saltville, VA  United States  36.922223 -81.878056          NaN
# 3       EUREKA, CA  United States        NaN        NaN          NaN
# 4       Canton, OH  United States        NaN        NaN          NaN
#
#   Airport.Name  ... Purpose.of.flight Air.carrier Total.Fatal.Injuries  \
# 0          NaN  ...          Personal         NaN                  2.0
# ...

# %%
# checking the tail of the dataset
df.tail()
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 88884  20221227106491           Accident      ERA23LA093  2022-12-26
# 88885  20221227106494           Accident      ERA23LA095  2022-12-26
# 88886  20221227106497           Accident      WPR23LA075  2022-12-26
# 88887  20221227106498           Accident      WPR23LA076  2022-12-26
# 88888  20221230106513           Accident      ERA23LA097  2022-12-29
#
#             Location        Country Latitude Longitude Airport.Code  \
# 88884  Annapolis, MD  United States      NaN       NaN          NaN
# 88885    Hampton, NH  United States      NaN       NaN          NaN
# 88886     Payson, AZ  United States  341525N  1112021W          PAN
# 88887     Morgan, UT  United States      NaN       NaN          NaN
# 88888     Athens, GA  United States      NaN       NaN          NaN
#
#       Airport.Name  ... Purpose.of.flight         Air.carrier  \
# 88884          NaN  ...          Personal                 NaN
# ...

# %%
# checking list of the columns 
df.columns
# Out:
# Index(['Event.Id', 'Investigation.Type', 'Accident.Number', 'Event.Date',
#        'Location', 'Country', 'Latitude', 'Longitude', 'Airport.Code',
#        'Airport.Name', 'Injury.Severity', 'Aircraft.damage',
#        'Aircraft.Category', 'Registration.Number', 'Make', 'Model',
#        'Amateur.Built', 'Number.of.Engines', 'Engine.Type', 'FAR.Description',
#        'Schedule', 'Purpose.of.flight', 'Air.carrier', 'Total.Fatal.Injuries',
#        'Total.Serious.Injuries', 'Total.Minor.Injuries', 'Total.Uninjured',
#        'Weather.Condition', 'Broad.phase.of.flight', 'Report.Status',
#        'Publication.Date'],
#       dtype='object')

# %%
# checking the summary statistics 
df.describe()
# Out:
#        Number.of.Engines  Total.Fatal.Injuries  Total.Serious.Injuries  \
# count       82805.000000          77488.000000            76379.000000
# mean            1.146585              0.647855                0.279881
# std             0.446510              5.485960                1.544084
# min             0.000000              0.000000                0.000000
# 25%             1.000000              0.000000                0.000000
# 50%             1.000000              0.000000                0.000000
# 75%             1.000000              0.000000                0.000000
# max             8.000000            349.000000              161.000000
#
#        Total.Minor.Injuries  Total.Uninjured
# count          76956.000000     82977.000000
# mean               0.357061         5.325440
# std                2.235625        27.913634
# min                0.000000         0.000000
# 25%                0.000000         0.000000
# 50%                0.000000         1.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88889 entries, 0 to 88888
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                88889 non-null  object
#  1   Investigation.Type      88889 non-null  object
#  2   Accident.Number         88889 non-null  object
#  3   Event.Date              88889 non-null  object
#  4   Location                88837 non-null  object
#  5   Country                 88663 non-null  object
#  6   Latitude                34382 non-null  object
#  7   Longitude               34373 non-null  object
#  8   Airport.Code            50132 non-null  object
#  9   Airport.Name            52704 non-null  object
#  10  Injury.Severity         87889 non-null  object
#  11  Aircraft.damage         85695 non-null  object
#  12  Aircraft.Category       32287 non-null  object
#  13  Registration.Number     87507 non-null  object
# ...

# %% [markdown]
# # Data Cleaning and Data Handling

# %% [markdown]
# There are quite alot of missing values in the rows we just expored in our dataset. We check the sum of all the missing data and the percentage as well

# %%
# checking the number of missing values in each column
df.isna().sum()
# Out:
# Event.Id                      0
# Investigation.Type            0
# Accident.Number               0
# Event.Date                    0
# Location                     52
# Country                     226
# Latitude                  54507
# Longitude                 54516
# Airport.Code              38757
# Airport.Name              36185
# Injury.Severity            1000
# Aircraft.damage            3194
# Aircraft.Category         56602
# Registration.Number        1382
# Make                         63
# Model                        92
# Amateur.Built               102
# Number.of.Engines          6084
# Engine.Type                7096
# FAR.Description           56866
# Schedule                  76307
# Purpose.of.flight          6192
# Air.carrier               72241
# Total.Fatal.Injuries      11401
# Total.Serious.Injuries    12510
# Total.Minor.Injuries      11933
# Total.Uninjured            5912
# Weather.Condition          4492
# Broad.phase.of.flight     27165
# ...

# %%
# Making a acopy fo the dataset
df_copy = df.copy()

# %%
#checking for duplicates in the dataset
df_copy.duplicated().sum()
# Out:
# 0

# %%
# checking and returning missing values as percentages 
def missing_values():
    """Function to check missing data in df
    
    Returns: (pd.Series) a series of the missing values as percentages
    """
    return df.isna().mean().sort_values(ascending=False)


missing_values()
# Out:
# Schedule                  0.858453
# Air.carrier               0.812710
# FAR.Description           0.639742
# Aircraft.Category         0.636772
# Longitude                 0.613304
# Latitude                  0.613203
# Airport.Code              0.436016
# Airport.Name              0.407081
# Broad.phase.of.flight     0.305606
# Publication.Date          0.154924
# Total.Serious.Injuries    0.140737
# Total.Minor.Injuries      0.134246
# Total.Fatal.Injuries      0.128261
# Engine.Type               0.079830
# Report.Status             0.071820
# Purpose.of.flight         0.069660
# Number.of.Engines         0.068445
# Total.Uninjured           0.066510
# Weather.Condition         0.050535
# Aircraft.damage           0.035932
# Registration.Number       0.015547
# Injury.Severity           0.011250
# Country                   0.002542
# Amateur.Built             0.001147
# Model                     0.001035
# Make                      0.000709
# Location                  0.000585
# ...

# %%
## checks the data types of each value in the 'Model' column
df_copy['Model'].apply(type)
# checks the count of each data type in the 'Model' column
df_copy['Model'].apply(type).value_counts()
# Converts 'Model' column values to strings and replaces spaces with hyphens
df_copy['Model'] =df_copy['Model'].astype(str).str.replace(' ', '-')

# %%
# Cleans column names by replacing dots with underscores
# and capitalizes the first letter of each word in column names
df.columns =df.columns.str.replace('.', '_').str.title()
df.columns
# Out:
# Index(['Event_Id', 'Investigation_Type', 'Accident_Number', 'Event_Date',
#        'Location', 'Country', 'Latitude', 'Longitude', 'Airport_Code',
#        'Airport_Name', 'Injury_Severity', 'Aircraft_Damage',
#        'Aircraft_Category', 'Registration_Number', 'Make', 'Model',
#        'Amateur_Built', 'Number_Of_Engines', 'Engine_Type', 'Far_Description',
#        'Schedule', 'Purpose_Of_Flight', 'Air_Carrier', 'Total_Fatal_Injuries',
#        'Total_Serious_Injuries', 'Total_Minor_Injuries', 'Total_Uninjured',
#        'Weather_Condition', 'Broad_Phase_Of_Flight', 'Report_Status',
#        'Publication_Date'],
#       dtype='object')

# %% [markdown]
# In my analysis, I'm going to focus on the most relevant data in regard to my final recommendations. I'll start  by dropping columns  with 25% missing values from this dataset. This will make our data easier to handle, without losing important information to our analysis.

# %%
# there are columns that have more that 25% missing data
#dropping them all
dropping_columns = ['Schedule','Air_Carrier','Far_Description', 'Aircraft_Category','Longitude','Latitude', 'Airport_Code','Airport_Name','Broad_Phase_Of_Flight']
df_clean = df.drop(columns = dropping_columns, inplace = True)
df_clean 

# should give us 22 columns, with rows unchanged

# %%
df.columns
# Out:
# Index(['Event_Id', 'Investigation_Type', 'Accident_Number', 'Event_Date',
#        'Location', 'Country', 'Latitude', 'Longitude', 'Airport_Code',
#        'Airport_Name', 'Injury_Severity', 'Aircraft_Damage',
#        'Aircraft_Category', 'Registration_Number', 'Make', 'Model',
#        'Amateur_Built', 'Number_Of_Engines', 'Engine_Type', 'Far_Description',
#        'Schedule', 'Purpose_Of_Flight', 'Air_Carrier', 'Total_Fatal_Injuries',
#        'Total_Serious_Injuries', 'Total_Minor_Injuries', 'Total_Uninjured',
#        'Weather_Condition', 'Broad_Phase_Of_Flight', 'Report_Status',
#        'Publication_Date'],
#       dtype='object')

# %% [markdown]
# Will creat a new column 'Total_Passengers', another wwith proportion of fatal injuries per accident 'Fatal_Injury_Proportion' and another one for uninjured per accident 'Uninjured_Proportion'.Will investigate rows where 'Fatal_Injuries_Proportion' has NaN data

# %%
# Creates a new column 'Total_Passengers'
df['Total_Passengers'] = df['Total_Fatal_Injuries'] + df['Total_Serious_Injuries'] + df['Total_Minor_Injuries'] + df['Total_Uninjured']

# %%
# Creates a new column with proportion of fatal injuries per accident
df['Fatal_Injury_Proportion'] =df['Total_Fatal_Injuries'] /df['Total_Passengers']

# %%
# Create a new column with proportion of uninjured per accident
df['Uninjured_Proportion'] =df['Total_Uninjured'] / df['Total_Passengers']

# %%
# Drop all NaNs in new 'injured' columns 
df.dropna(subset=['Total_Fatal_Injuries', 'Total_Serious_Injuries', 'Total_Minor_Injuries', 'Total_Uninjured', 'Fatal_Injury_Proportion', 'Uninjured_Proportion'], inplace=True)
df
# Out:
#              Event_Id Investigation_Type Accident_Number  Event_Date  \
# 0      20001218X45444           Accident      SEA87LA080  1948-10-24
# 1      20001218X45447           Accident      LAX94LA336  1962-07-19
# 3      20001218X45448           Accident      LAX96LA321  1977-06-19
# 6      20001218X45446           Accident      CHI81LA106  1981-08-01
# 7      20020909X01562           Accident      SEA82DA022  1982-01-01
# ...               ...                ...             ...         ...
# 88882  20221222106486           Accident      CEN23LA068  2022-12-21
# 88883  20221228106502           Accident      GAA23WA046  2022-12-22
# 88884  20221227106491           Accident      ERA23LA093  2022-12-26
# 88886  20221227106497           Accident      WPR23LA075  2022-12-26
# 88888  20221230106513           Accident      ERA23LA097  2022-12-29
#
#               Location        Country Latitude Longitude Airport_Code  \
# ...

# %%
# dropping columns with more that 25% missing data
dropping_columns = ['Schedule','Air_Carrier','Far_Description', 'Aircraft_Category','Longitude','Latitude', 'Airport_Code','Airport_Name','Broad_Phase_Of_Flight']
df_clean = df.drop(columns = dropping_columns)
df_clean 

# should give us 22 columns, with rows unchanged
# Out:
#              Event_Id Investigation_Type Accident_Number  Event_Date  \
# 0      20001218X45444           Accident      SEA87LA080  1948-10-24
# 1      20001218X45447           Accident      LAX94LA336  1962-07-19
# 3      20001218X45448           Accident      LAX96LA321  1977-06-19
# 6      20001218X45446           Accident      CHI81LA106  1981-08-01
# 7      20020909X01562           Accident      SEA82DA022  1982-01-01
# ...               ...                ...             ...         ...
# 88882  20221222106486           Accident      CEN23LA068  2022-12-21
# 88883  20221228106502           Accident      GAA23WA046  2022-12-22
# 88884  20221227106491           Accident      ERA23LA093  2022-12-26
# 88886  20221227106497           Accident      WPR23LA075  2022-12-26
# 88888  20221230106513           Accident      ERA23LA097  2022-12-29
#
#               Location        Country Injury_Severity Aircraft_Damage  \
# ...

# %%
# Drop all NaNs in new 'injured' columns 
df.dropna(subset=['Total_Fatal_Injuries', 'Total_Serious_Injuries', 'Total_Minor_Injuries', 'Total_Uninjured', 'Fatal_Injury_Proportion', 'Uninjured_Proportion'], inplace=True)
df
# Out:
#              Event_Id Investigation_Type Accident_Number  Event_Date  \
# 0      20001218X45444           Accident      SEA87LA080  1948-10-24
# 1      20001218X45447           Accident      LAX94LA336  1962-07-19
# 3      20001218X45448           Accident      LAX96LA321  1977-06-19
# 6      20001218X45446           Accident      CHI81LA106  1981-08-01
# 7      20020909X01562           Accident      SEA82DA022  1982-01-01
# ...               ...                ...             ...         ...
# 88882  20221222106486           Accident      CEN23LA068  2022-12-21
# 88883  20221228106502           Accident      GAA23WA046  2022-12-22
# 88884  20221227106491           Accident      ERA23LA093  2022-12-26
# 88886  20221227106497           Accident      WPR23LA075  2022-12-26
# 88888  20221230106513           Accident      ERA23LA097  2022-12-29
#
#               Location        Country Latitude Longitude Airport_Code  \
# ...

# %%
# checks the data types of each value in the 'Model' column
df['Model'].apply(type)
# Out:
# 0        <class 'str'>
# 1        <class 'str'>
# 3        <class 'str'>
# 6        <class 'str'>
# 7        <class 'str'>
#              ...
# 88882    <class 'str'>
# 88883    <class 'str'>
# 88884    <class 'str'>
# 88886    <class 'str'>
# 88888    <class 'str'>
# Name: Model, Length: 73276, dtype: object

# %%
# checks the count of each data type in the 'Model' column
df['Model'].apply(type).value_counts()
# Out:
# Model
# <class 'str'>      73225
# <class 'float'>       51
# Name: count, dtype: int64

# %%
# Converts 'Model' column values to strings and replaces spaces with hyphens
df['Model'] = df['Model'].astype(str).str.replace(' ', '-')
